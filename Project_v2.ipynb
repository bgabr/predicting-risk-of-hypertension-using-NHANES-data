# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as  stats
from scipy.stats import skew
import seaborn as sns
from scipy.stats import norm, kurtosis

# %%
def combinedata(_2017_2020,_2015_2016,_2013_2014,_2011_2012,_2009_2010,_2007_2008):
    _17_20_list = _2017_2020.columns.tolist()
    _15_16_list = _2015_2016.columns.tolist()
    _13_14_list = _2013_2014.columns.tolist()
    _11_12_list = _2011_2012.columns.tolist()
    _09_10_list = _2009_2010.columns.tolist()
    _07_08_list = _2007_2008.columns.tolist()
    
    intersect_col = set(_17_20_list).intersection(_15_16_list).intersection(_13_14_list).intersection(_11_12_list).intersection(_09_10_list).intersection(_07_08_list)
    
    _17_20_filtered = pd.DataFrame(_2017_2020, columns=intersect_col)
    _15_16_filtered = pd.DataFrame(_2015_2016, columns=intersect_col)
    _13_14_filtered = pd.DataFrame(_2013_2014, columns=intersect_col)
    _11_12_filtered = pd.DataFrame(_2011_2012, columns=intersect_col)
    _09_10_filtered = pd.DataFrame(_2009_2010, columns=intersect_col)
    _07_08_filtered = pd.DataFrame(_2007_2008, columns=intersect_col)
    print(intersect_col)
    
    _final = _17_20_filtered.append(_15_16_filtered)
    _final = _final.append(_13_14_filtered)
    _final = _final.append(_11_12_filtered)
    _final = _final.append(_09_10_filtered)
    _final = _final.append(_07_08_filtered)
    
    return _final

# %%
demo_2017_2020 = pd.read_sas("./demographic/demo_2017_2020.XPT");
demo_2015_2016 = pd.read_sas("./demographic/demo_2015_2016.XPT");
demo_2013_2014 = pd.read_sas("./demographic/demo_2013_2014.XPT");
demo_2011_2012 = pd.read_sas("./demographic/demo_2011_2012.XPT");
demo_2009_2010 = pd.read_sas("./demographic/demo_2009_2010.XPT");
demo_2007_2008 = pd.read_sas("./demographic/demo_2007_2008.XPT");

demo_final = combinedata(demo_2017_2020,demo_2015_2016,demo_2013_2014,demo_2011_2012,demo_2009_2010,demo_2007_2008)
# Out:
# {'RIDAGEMN', 'SIAPROXY', 'SDMVSTRA', 'SIALANG', 'RIDSTATR', 'SEQN', 'MIAPROXY', 'RIDRETH1', 'SIAINTRP', 'FIAINTRP', 'SDMVPSU', 'FIALANG', 'RIAGENDR', 'MIALANG', 'DMDEDUC2', 'MIAINTRP', 'FIAPROXY', 'RIDEXMON', 'RIDEXPRG', 'INDFMPIR', 'SDDSRVYR', 'RIDAGEYR'}

# %%
diet_2017_2020 = pd.read_sas("./diet/diet_17_20.XPT");
diet_2015_2016 = pd.read_sas("./diet/diet_15_16.XPT");
diet_2013_2014 = pd.read_sas("./diet/diet_13_14.XPT");
diet_2011_2012 = pd.read_sas("./diet/diet_11_12.XPT");
diet_2009_2010 = pd.read_sas("./diet/diet_09_10.XPT");
diet_2007_2008 = pd.read_sas("./diet/diet_07_08.XPT");

diet_final = combinedata(diet_2017_2020,diet_2015_2016,diet_2013_2014,diet_2011_2012,diet_2009_2010,diet_2007_2008)
# Out:
# {'DSQTFA', 'DSQTVB12', 'DSQTFDFE', 'DSDANCNT', 'DSQTCHOL', 'DSQTLYCO', 'DSQTVB1', 'SEQN', 'DSQTPOTA', 'DSQTCOPP', 'DSQTMAGN', 'DSQTSFAT', 'DSQTVC', 'DSQTVB6', 'DSQTPHOS', 'DSQTFIBE', 'DSQTTFAT', 'DSQTCHL', 'DSQTIRON', 'DSQTVB2', 'DSQTSODI', 'DSQTSELE', 'DSQTPFAT', 'DSDCOUNT', 'DSQTZINC', 'DSQTCAFF', 'DSQTCALC', 'DSQTPROT', 'DSQTVD', 'DSQTMFAT', 'DSD010', 'DSQTSUGR', 'DSD010AN', 'DSQTVK', 'DSQTKCAL', 'DSQTCARB', 'DSQTLZ', 'DSQTNIAC'}

# %%
#blood pressure info for labelling

bp_2017_2020 = pd.read_sas("./blood pressure/bp_17_20.XPT");
bp_2015_2016 = pd.read_sas("./blood pressure/bp_15_16.XPT");
bp_2013_2014 = pd.read_sas("./blood pressure/bp_13_14.XPT");
bp_2011_2012 = pd.read_sas("./blood pressure/bp_11_12.XPT");
bp_2009_2010 = pd.read_sas("./blood pressure/bp_09_10.XPT");
bp_2007_2008 = pd.read_sas("./blood pressure/bp_07_08.XPT");

bp_final = combinedata(bp_2017_2020,bp_2015_2016,bp_2013_2014,bp_2011_2012,bp_2009_2010,bp_2007_2008)
# Out:
# {'BPQ070', 'BPQ080', 'BPQ040A', 'BPD035', 'SEQN', 'BPQ100D', 'BPQ030', 'BPQ020', 'BPQ090D', 'BPQ060', 'BPQ050A'}

# %%
#alcohol data
#alc_2017_2020 have different column names compared to prev years

alc_2017_2020 = pd.read_sas("./alcohol/alc_17_20.XPT");
alc_2015_2016 = pd.read_sas("./alcohol/alc_15_16.XPT");
alc_2013_2014 = pd.read_sas("./alcohol/alc_13_14.XPT");
alc_2011_2012 = pd.read_sas("./alcohol/alc_11_12.XPT");
alc_2009_2010 = pd.read_sas("./alcohol/alc_09_10.XPT");
alc_2007_2008 = pd.read_sas("./alcohol/alc_07_08.XPT");

alc_final = combinedata(alc_2017_2020,alc_2015_2016,alc_2013_2014,alc_2011_2012,alc_2009_2010,alc_2007_2008)
# Out:
# {'SEQN', 'ALQ130'}

# %%
print(alc_2017_2020.columns)
print(alc_2015_2016.columns)
print(alc_2013_2014.columns)
# Out:
# Index(['SEQN', 'ALQ111', 'ALQ121', 'ALQ130', 'ALQ142', 'ALQ270', 'ALQ280',
#        'ALQ290', 'ALQ151', 'ALQ170'],
#       dtype='object')
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ120Q', 'ALQ120U', 'ALQ130', 'ALQ141Q',
#        'ALQ141U', 'ALQ151', 'ALQ160'],
#       dtype='object')
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ120Q', 'ALQ120U', 'ALQ130', 'ALQ141Q',
#        'ALQ141U', 'ALQ151', 'ALQ160'],
#       dtype='object')

# %%
#total cholesterol data

tchol_2017_2020 = pd.read_sas("./cholesterol/tchol_17_20.XPT");
tchol_2015_2016 = pd.read_sas("./cholesterol/tchol_15_16.XPT");
tchol_2013_2014 = pd.read_sas("./cholesterol/tchol_13_14.XPT");
tchol_2011_2012 = pd.read_sas("./cholesterol/tchol_11_12.XPT");
tchol_2009_2010 = pd.read_sas("./cholesterol/tchol_09_10.XPT");
tchol_2007_2008 = pd.read_sas("./cholesterol/tchol_07_08.XPT");

tchol_final = combinedata(tchol_2017_2020,tchol_2015_2016,tchol_2013_2014,tchol_2011_2012,tchol_2009_2010,tchol_2007_2008)
# Out:
# {'LBXTC', 'LBDTCSI', 'SEQN'}

# %%
#diabetes data

di_2017_2020 = pd.read_sas("./diabetes/diabetes_17_20.XPT");
di_2015_2016 = pd.read_sas("./diabetes/diabetes_15_16.XPT");
di_2013_2014 = pd.read_sas("./diabetes/diabetes_13_14.XPT");
di_2011_2012 = pd.read_sas("./diabetes/diabetes_11_12.XPT");
di_2009_2010 = pd.read_sas("./diabetes/diabetes_09_10.XPT");
di_2007_2008 = pd.read_sas("./diabetes/diabetes_07_08.XPT");

diabetes_final = combinedata(di_2017_2020,di_2015_2016,di_2013_2014,di_2011_2012,di_2009_2010,di_2007_2008)
# Out:
# {'DIQ050', 'DID350', 'DID040', 'DIQ350U', 'SEQN', 'DIQ230', 'DID260', 'DIQ360', 'DIQ180', 'DID250', 'DIQ080', 'DIQ260U', 'DIQ010', 'DID060', 'DIQ240', 'DIQ060U', 'DIQ160'}

# %%
#income data

inc_2017_2020 = pd.read_sas("./income/inc_17_20.XPT");
inc_2015_2016 = pd.read_sas("./income/inc_15_16.XPT");
inc_2013_2014 = pd.read_sas("./income/inc_13_14.XPT");
inc_2011_2012 = pd.read_sas("./income/inc_11_12.XPT");
inc_2009_2010 = pd.read_sas("./income/inc_09_10.XPT");
inc_2007_2008 = pd.read_sas("./income/inc_07_08.XPT");

income_final = combinedata(inc_2017_2020,inc_2015_2016,inc_2013_2014,inc_2011_2012,inc_2009_2010,inc_2007_2008)
# Out:
# {'INDFMMPC', 'SEQN', 'INDFMMPI'}

# %%
#kidney disease data

kid_2017_2020 = pd.read_sas("./kidney disease/kidney_17_20.XPT");
kid_2015_2016 = pd.read_sas("./kidney disease/kidney_15_16.XPT");
kid_2013_2014 = pd.read_sas("./kidney disease/kidney_13_14.XPT");
kid_2011_2012 = pd.read_sas("./kidney disease/kidney_11_12.XPT");
kid_2009_2010 = pd.read_sas("./kidney disease/kidney_09_10.XPT");
kid_2007_2008 = pd.read_sas("./kidney disease/kidney_07_08.XPT");

kidney_final = combinedata(kid_2017_2020,kid_2015_2016,kid_2013_2014,kid_2011_2012,kid_2009_2010,kid_2007_2008)
# Out:
# {'KIQ005', 'KIQ050', 'KIQ430', 'KIQ010', 'KIQ044', 'SEQN', 'KIQ480', 'KIQ026', 'KIQ022', 'KIQ052', 'KIQ450', 'KIQ470', 'KIQ046', 'KIQ042', 'KIQ025'}

# %%
#physical activity data

pa_2017_2020 = pd.read_sas("./physical activity/pa_17_20.XPT");
pa_2015_2016 = pd.read_sas("./physical activity/pa_15_16.XPT");
pa_2013_2014 = pd.read_sas("./physical activity/pa_13_14.XPT");
pa_2011_2012 = pd.read_sas("./physical activity/pa_11_12.XPT");
pa_2009_2010 = pd.read_sas("./physical activity/pa_09_10.XPT");
pa_2007_2008 = pd.read_sas("./physical activity/pa_07_08.XPT");

pa_final = combinedata(pa_2017_2020,pa_2015_2016,pa_2013_2014,pa_2011_2012,pa_2009_2010,pa_2007_2008)
# Out:
# {'PAQ640', 'PAQ635', 'PAQ655', 'PAQ620', 'PAQ610', 'PAD645', 'PAQ650', 'SEQN', 'PAQ605', 'PAD615', 'PAD680', 'PAQ665', 'PAQ625', 'PAD660', 'PAQ670', 'PAD675', 'PAD630'}

# %%
#smoking status data

smoke_2017_2020 = pd.read_sas("./smoking/smoke_17_20.XPT");
smoke_2015_2016 = pd.read_sas("./smoking/smoke_15_16.XPT");
smoke_2013_2014 = pd.read_sas("./smoking/smoke_13_14.XPT");
smoke_2011_2012 = pd.read_sas("./smoking/smoke_11_12.XPT");
smoke_2009_2010 = pd.read_sas("./smoking/smoke_09_10.XPT");
smoke_2007_2008 = pd.read_sas("./smoking/smoke_07_08.XPT");

smoke_final = combinedata(smoke_2017_2020,smoke_2015_2016,smoke_2013_2014,smoke_2011_2012,smoke_2009_2010,smoke_2007_2008)
# Out:
# {'SMD630', 'SMAQUEX2', 'SEQN', 'SMD057', 'SMD030', 'SMD650', 'SMQ020', 'SMQ050U', 'SMD100MN', 'SMQ670', 'SMD100FL', 'SMQ040', 'SMD641', 'SMQ050Q'}

# %%
#triglycerides data
#2017-2020 data have some different columns

trigly_2017_2020 = pd.read_sas("./triglycerides/trigly_17_20.XPT");
trigly_2015_2016 = pd.read_sas("./triglycerides/trigly_15_16.XPT");
trigly_2013_2014 = pd.read_sas("./triglycerides/trigly_13_14.XPT");
trigly_2011_2012 = pd.read_sas("./triglycerides/trigly_11_12.XPT");
trigly_2009_2010 = pd.read_sas("./triglycerides/trigly_09_10.XPT");
trigly_2007_2008 = pd.read_sas("./triglycerides/trigly_07_08.XPT");

trigly_final = combinedata(trigly_2017_2020,trigly_2015_2016,trigly_2013_2014,trigly_2011_2012,trigly_2009_2010,trigly_2007_2008)
# Out:
# {'SEQN', 'LBDTRSI', 'LBXTR', 'LBDLDLSI', 'LBDLDL'}

# %%
print(trigly_2017_2020.columns)
print(trigly_2015_2016.columns)
print(trigly_2013_2014.columns)
# Out:
# Index(['SEQN', 'WTSAFPRP', 'LBXTR', 'LBDTRSI', 'LBDLDL', 'LBDLDLSI', 'LBDLDLM',
#        'LBDLDMSI', 'LBDLDLN', 'LBDLDNSI'],
#       dtype='object')
# Index(['SEQN', 'WTSAF2YR', 'LBXTR', 'LBDTRSI', 'LBDLDL', 'LBDLDLSI'], dtype='object')
# Index(['SEQN', 'WTSAF2YR', 'LBXTR', 'LBDTRSI', 'LBDLDL', 'LBDLDLSI'], dtype='object')

# %%
#weight data

weight_2017_2020 = pd.read_sas("./weight/weight_17_20.XPT");
weight_2015_2016 = pd.read_sas("./weight/weight_15_16.XPT");
weight_2013_2014 = pd.read_sas("./weight/weight_13_14.XPT");
weight_2011_2012 = pd.read_sas("./weight/weight_11_12.XPT");
weight_2009_2010 = pd.read_sas("./weight/weight_09_10.XPT");
weight_2007_2008 = pd.read_sas("./weight/weight_07_08.XPT");

weight_final = combinedata(weight_2017_2020,weight_2015_2016,weight_2013_2014,weight_2011_2012,weight_2009_2010,weight_2007_2008)
# Out:
# {'BMXHEAD', 'BMXBMI', 'BMIHEAD', 'BMXWT', 'SEQN', 'BMIARMC', 'BMXHT', 'BMXRECUM', 'BMIWAIST', 'BMIARML', 'BMXLEG', 'BMILEG', 'BMIWT', 'BMXARML', 'BMIRECUM', 'BMDSTATS', 'BMIHT', 'BMXARMC', 'BMXWAIST'}

# %%
#blood pressure reading
#2017-2020 data have different column names

bprdg_2017_2020 = pd.read_sas("./blood pressure reading/bp_rdg_os_17_20.XPT");
bprdg_2015_2016 = pd.read_sas("./blood pressure reading/bp_rdg_15_16.XPT");
bprdg_2013_2014 = pd.read_sas("./blood pressure reading/bp_rdg_13_14.XPT");
bprdg_2011_2012 = pd.read_sas("./blood pressure reading/bp_rdg_11_12.XPT");
bprdg_2009_2010 = pd.read_sas("./blood pressure reading/bp_rdg_09_10.XPT");
bprdg_2007_2008 = pd.read_sas("./blood pressure reading/bp_rdg_07_08.XPT");

# %%
print(bprdg_2017_2020.columns)
print(bprdg_2015_2016.columns)
# Out:
# Index(['SEQN', 'BPAOARM', 'BPAOCSZ', 'BPXOSY1', 'BPXODI1', 'BPXOSY2',
#        'BPXODI2', 'BPXOSY3', 'BPXODI3', 'BPXOPLS1', 'BPXOPLS2', 'BPXOPLS3'],
#       dtype='object')
# Index(['SEQN', 'PEASCCT1', 'BPXCHR', 'BPAARM', 'BPACSZ', 'BPXPLS', 'BPXPULS',
#        'BPXPTY', 'BPXML1', 'BPXSY1', 'BPXDI1', 'BPAEN1', 'BPXSY2', 'BPXDI2',
#        'BPAEN2', 'BPXSY3', 'BPXDI3', 'BPAEN3', 'BPXSY4', 'BPXDI4', 'BPAEN4'],
#       dtype='object')

# %%
def combinedata_v2(_2015_2016,_2013_2014,_2011_2012,_2009_2010,_2007_2008):
    _15_16_list = _2015_2016.columns.tolist()
    _13_14_list = _2013_2014.columns.tolist()
    _11_12_list = _2011_2012.columns.tolist()
    _09_10_list = _2009_2010.columns.tolist()
    _07_08_list = _2007_2008.columns.tolist()
    
    intersect_col = set(_15_16_list).intersection(_13_14_list).intersection(_11_12_list).intersection(_09_10_list).intersection(_07_08_list)
    
    _15_16_filtered = pd.DataFrame(_2015_2016, columns=intersect_col)
    _13_14_filtered = pd.DataFrame(_2013_2014, columns=intersect_col)
    _11_12_filtered = pd.DataFrame(_2011_2012, columns=intersect_col)
    _09_10_filtered = pd.DataFrame(_2009_2010, columns=intersect_col)
    _07_08_filtered = pd.DataFrame(_2007_2008, columns=intersect_col)
    print(intersect_col)
    
    _final = _15_16_filtered.append(_13_14_filtered)
    _final = _final.append(_11_12_filtered)
    _final = _final.append(_09_10_filtered)
    _final = _final.append(_07_08_filtered)
    
    return _final

# %%
col= bprdg_2017_2020.loc[:,'BPXOPLS1':'BPXOPLS3']

bprdg_2017_2020['BPXPLS']= col.mean(axis=1)

# %%
bprdg_final= combinedata_v2(bprdg_2015_2016,bprdg_2013_2014,bprdg_2011_2012,bprdg_2009_2010,bprdg_2007_2008)
bprdg_final= bprdg_final.append(bprdg_2017_2020)
# Out:
# {'BPXPULS', 'BPXDI1', 'BPAARM', 'BPXSY2', 'BPAEN1', 'BPXDI2', 'BPXDI3', 'BPACSZ', 'BPXML1', 'SEQN', 'BPXPTY', 'BPXPLS', 'BPXCHR', 'BPAEN3', 'BPXSY1', 'PEASCCT1', 'BPXSY3', 'BPXSY4', 'BPAEN2', 'BPAEN4', 'BPXDI4'}

# %%
bprdg_final.columns
# Out:
# Index(['BPXPULS', 'BPXDI1', 'BPAARM', 'BPXSY2', 'BPAEN1', 'BPXDI2', 'BPXDI3',
#        'BPACSZ', 'BPXML1', 'SEQN', 'BPXPTY', 'BPXPLS', 'BPXCHR', 'BPAEN3',
#        'BPXSY1', 'PEASCCT1', 'BPXSY3', 'BPXSY4', 'BPAEN2', 'BPAEN4', 'BPXDI4',
#        'BPAOARM', 'BPAOCSZ', 'BPXOSY1', 'BPXODI1', 'BPXOSY2', 'BPXODI2',
#        'BPXOSY3', 'BPXODI3', 'BPXOPLS1', 'BPXOPLS2', 'BPXOPLS3'],
#       dtype='object')

# %%
final_df= pd.merge(demo_final, diet_final,on=['SEQN'])
final_df= pd.merge(final_df, alc_final,on=['SEQN'])
final_df= pd.merge(final_df, tchol_final,on=['SEQN'])
final_df= pd.merge(final_df, diabetes_final,on=['SEQN'])
final_df= pd.merge(final_df, income_final,on=['SEQN'])
final_df= pd.merge(final_df, kidney_final,on=['SEQN'])
final_df= pd.merge(final_df, pa_final,on=['SEQN'])
final_df= pd.merge(final_df, smoke_final, on=['SEQN'])
final_df= pd.merge(final_df, trigly_final, on=['SEQN'])
final_df= pd.merge(final_df, weight_final, on=['SEQN'])
final_df= pd.merge(final_df, bprdg_final, on=['SEQN'])
final_df= pd.merge(final_df, bp_final, on=['SEQN'])

# %%
final_df.shape
# Out:
# (17847, 186)

# %%
final_df.BPQ020.value_counts()
# Out:
# 2.0    11095
# 1.0     6729
# 9.0       23
# Name: BPQ020, dtype: int64

# %%
# final_df.to_csv(r'C:\Users\chery\Desktop\Data301\project\final.csv', index=None)

# %%
# final= pd.read_csv('final.csv')
# final.shape

# %%
# final.set_index('SEQN')

# %% [markdown]
# ### Feature selection using correlation values:

# %%
final_isnull_df = final_df.isnull().sum().sort_values().to_frame("count")
final_isnull_df
# Out:
#           count
# PAQ635        0
# BMDSTATS      0
# SMAQUEX2      0
# DIQ010        0
# PAQ665        0
# ...         ...
# BMXRECUM  17847
# BMIHEAD   17847
# BMXHEAD   17847
# SMD630    17847
# BMIRECUM  17847
#
# [186 rows x 1 columns]

# %% [markdown]
# Comment: a lot of columns contains more than half of their value as null (some columns has all their rows as null) and i will remove all columns before progressing to feature selections.

# %%
def has_nan(col, threshold=8500):
    return col.isnull().sum() > threshold

# dropping columns with more than 50% values are missing
final_df_2 = final_df.loc[:, ~final_df.apply(has_nan)]

# %%
#final_df_2.head()

# %%
# the number of null values in each feature ( column )
final_isnull_df = final_df_2.isnull().sum().sort_values().to_frame("count")
final_isnull_df
# Out:
#           count
# SIAPROXY      0
# BMDSTATS      0
# DIQ010        0
# PAQ620        0
# PAQ650        0
# ...         ...
# BPXDI3     5142
# BPXDI1     5293
# BPXSY1     5293
# BPQ090D    6693
# ALQ130     6908
#
# [80 rows x 1 columns]

# %%
# Name of all the features that contain more than 50% non-null value
final_df_2.columns
# Out:
# Index(['SIAPROXY', 'SDMVSTRA', 'SIALANG', 'RIDSTATR', 'SEQN', 'MIAPROXY',
#        'RIDRETH1', 'SIAINTRP', 'FIAINTRP', 'SDMVPSU', 'FIALANG', 'RIAGENDR',
#        'MIALANG', 'DMDEDUC2', 'MIAINTRP', 'FIAPROXY', 'RIDEXMON', 'INDFMPIR',
#        'SDDSRVYR', 'RIDAGEYR', 'DSDANCNT', 'DSDCOUNT', 'DSD010', 'DSD010AN',
#        'ALQ130', 'LBXTC', 'LBDTCSI', 'DIQ050', 'DIQ180', 'DIQ010', 'DIQ160',
#        'INDFMMPC', 'INDFMMPI', 'KIQ005', 'KIQ044', 'KIQ480', 'KIQ026',
#        'KIQ022', 'KIQ046', 'KIQ042', 'PAQ635', 'PAQ620', 'PAQ650', 'PAQ605',
#        'PAD680', 'PAQ665', 'SMAQUEX2', 'SMQ020', 'LBDTRSI', 'LBXTR',
#        'LBDLDLSI', 'LBDLDL', 'BMXBMI', 'BMXWT', 'BMXHT', 'BMXLEG', 'BMXARML',
#        'BMDSTATS', 'BMXARMC', 'BMXWAIST', 'BPXPULS', 'BPXDI1', 'BPAARM',
#        'BPXSY2', 'BPAEN1', 'BPXDI2', 'BPXDI3', 'BPACSZ', 'BPXML1', 'BPXPTY',
#        'BPXPLS', 'BPAEN3', 'BPXSY1', 'BPXSY3', 'BPAEN2', 'BPQ070', 'BPQ080',
#        'BPQ020', 'BPQ090D', 'BPQ060'],
#       dtype='object')

# %% [markdown]
# Comment: in this list of features, there are many categorical features that contains value 7 for 'refused' and 9 for 'don't know', therefore I decided to remove all instances (row) that contain 7 or 9.

# %%
values = [7,8,9,77,99,777,999,7777,9999]
final_df_2 = final_df_2[final_df_2["ALQ130"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DSD010AN"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DSDCOUNT"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DSDANCNT"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DSD010"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DIQ010"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DIQ180"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DIQ160"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["DIQ050"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["INDFMMPC"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["KIQ044"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["KIQ480"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["KIQ005"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["KIQ042"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["KIQ046"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["PAQ620"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["PAQ605"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["PAD680"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["PAQ650"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["PAQ635"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["BPXPTY"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["BPAEN3"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["BPAEN1"].isin(values) == False]
final_df_2 = final_df_2[final_df_2["BPQ020"].isin(values) == False]

# %%
numeric_featuers = final_df_2[['INDFMPIR','DSDCOUNT','DSDANCNT','ALQ130',
                             'LBDTCSI', 'LBXTC', 'KIQ480', 'PAD680', 'LBXTR',
                             'LBDTRSI', 'LBDLDL', 'LBDLDLSI', 'BPXDI2', 'BPXDI3',
                             'BPXML1', 'BPXSY2', 'BPXSY1', 'BPXDI1', 'BPXPLS', 'BPXSY3']]

# %%
categorical_features = ['DMDEDUC2','SIAINTRP','FIAINTRP','MIAPROXY','SIAPROXY','FIALANG',
                        'RIDSTATR','MIALANG','RIAGENDR','RIDRETH1','FIAPROXY','MIAINTRP',
                        'RIDEXMON','SIALANG','DSD010AN','DSDANCNT','DSD010','DIQ010','DIQ180',
                        'DIQ160','DIQ050','INDFMMPC','KIQ022','KIQ044','KIQ480','KIQ005',
                        'KIQ026','KIQ042','KIQ046','PAQ620','PAQ605','PAD680','PAQ650',
                        'PAQ665','PAQ635','SMQ020','BPAARM','BPXPULS','BPAEN3']

# %% [markdown]
# ### Feature selection on categorical variables

# %% [markdown]
# #### Correlation between categorical variables to the response varaible

# %% [markdown]
# Comment: I will be using chi square test to test the correlation between 2 categorical variables (1 predictor and 1 response variable). The chisquare function involves:
#
# - Assumption H0: the features are not related to each other
# - Assumption H1: the features are related to each other
# - The function returns the p-value, if p-value is high, we don't reject H0 and if p-value is below 0.05 then we accept H1.
#
# Reference: https://thinkingneuron.com/how-to-measure-the-correlation-between-two-categorical-variables-in-python/

# %%
from sklearn.impute import SimpleImputer
from scipy.stats import chi2_contingency
import numpy as np

def categorical_correlation(feature):
    print(feature)
    test_feat = final_df_2[[feature]]
    imp_test = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    test_feat = imp_test.fit_transform(test_feat)
    test_feat = pd.DataFrame(test_feat, columns=[feature])
    CrosstabResult=pd.crosstab(index=test_feat[feature],columns=final_df_2['BPQ020'])
    print("Cross table result:")
    print(CrosstabResult)
    ChiSqResult = chi2_contingency(CrosstabResult)
    
    print("\nchisquare p-value:")
    print(ChiSqResult[1])
    print("\n")

# %%
for i in range(len(categorical_features)):
    categorical_correlation(categorical_features[i])
# Out:
# DMDEDUC2
# Cross table result:
# BPQ020     1.0   2.0
# DMDEDUC2
# 1.0        564   963
# 2.0        786  1290
# 3.0       1254  2026
# 4.0       1603  2704
# 5.0       1270  2133
# 7.0          1     4
# 9.0          5     6
#
# chisquare p-value:
# 0.8995366298122234
#
#
# SIAINTRP
# Cross table result:
# BPQ020     1.0   2.0
# SIAINTRP
# 1.0        187   313
# 2.0       5296  8813
#
# chisquare p-value:
# 0.9881304691379736
#
#
# FIAINTRP
# Cross table result:
# BPQ020     1.0   2.0
# FIAINTRP
# 1.0        143   223
# 2.0       5340  8903
#
# chisquare p-value:
# 0.5745825694540079
#
#
# MIAPROXY
# Cross table result:
# BPQ020     1.0   2.0
# MIAPROXY
# 1.0         45    50
# 2.0       5438  9076
#
# chisquare p-value:
# 0.06007133519079628
#
#
# SIAPROXY
# Cross table result:
# BPQ020     1.0   2.0
# SIAPROXY
# 1.0         60    74
# 2.0       5423  9052
#
# chisquare p-value:
# 0.09887990087651088
#
#
# FIALANG
# Cross table result:
# BPQ020    1.0   2.0
# FIALANG
# 1.0      5008  8310
# 2.0       475   816
#
# chisquare p-value:
# 0.5865568802019268
#
#
# RIDSTATR
# Cross table result:
# BPQ020     1.0   2.0
# RIDSTATR
# 2.0       5483  9126
#
# chisquare p-value:
# 1.0
#
#
# MIALANG
# Cross table result:
# BPQ020    1.0   2.0
# MIALANG
# 1.0      4947  8276
# 2.0       536   850
#
# chisquare p-value:
# 0.37197512094836893
#
#
# RIAGENDR
# Cross table result:
# BPQ020     1.0   2.0
# RIAGENDR
# 1.0       2733  4280
# 2.0       2750  4846
#
# chisquare p-value:
# 0.0005948986299359694
#
#
# RIDRETH1
# Cross table result:
# BPQ020     1.0   2.0
# RIDRETH1
# 1.0        779  1330
# 2.0        600   976
# 3.0       2116  3618
# 4.0       1283  2024
# 5.0        705  1178
#
# chisquare p-value:
# 0.44168331651248205
#
#
# FIAPROXY
# Cross table result:
# BPQ020     1.0   2.0
# FIAPROXY
# 1.0          3     8
# 2.0       5480  9118
#
# chisquare p-value:
# 0.6954278623397392
#
#
# MIAINTRP
# Cross table result:
# BPQ020     1.0   2.0
# MIAINTRP
# 1.0        144   273
# 2.0       5339  8853
#
# chisquare p-value:
# 0.21793219368898095
#
#
# RIDEXMON
# Cross table result:
# BPQ020     1.0   2.0
# RIDEXMON
# 1.0       2670  4477
# 2.0       2813  4649
#
# chisquare p-value:
# 0.6844942755694436
#
#
# SIALANG
# Cross table result:
# BPQ020    1.0   2.0
# SIALANG
# 1.0      4785  7950
# 2.0       698  1176
#
# chisquare p-value:
# 0.8045382149228665
#
#
# DSD010AN
# Cross table result:
# BPQ020     1.0   2.0
# DSD010AN
# 1.0        683  1124
# 2.0       4800  8002
#
# chisquare p-value:
# 0.8232864535651171
#
#
# DSDANCNT
# Cross table result:
# BPQ020         1.0   2.0
# DSDANCNT
# 5.397605e-79  4800  8002
# 1.000000e+00   661  1096
# 2.000000e+00    21    28
# 3.000000e+00     1     0
#
# chisquare p-value:
# 0.5181366365289544
#
#
# DSD010
# Cross table result:
# BPQ020   1.0   2.0
# DSD010
# 1.0     2763  4579
# 2.0     2720  4547
#
# chisquare p-value:
# 0.8129074998044559
#
#
# DIQ010
# Cross table result:
# BPQ020   1.0   2.0
# DIQ010
# 1.0      780  1291
# 2.0     4582  7604
# 3.0      121   231
#
# chisquare p-value:
# 0.46396102383980575
#
#
# DIQ180
# Cross table result:
# BPQ020   1.0   2.0
# DIQ180
# 1.0     3206  5247
# 2.0     2277  3879
#
# chisquare p-value:
# 0.2542177066667235
#
#
# DIQ160
# Cross table result:
# BPQ020   1.0   2.0
# DIQ160
# 1.0      379   567
# 2.0     5104  8559
#
# chisquare p-value:
# 0.10347667004963788
#
#
# DIQ050
# Cross table result:
# BPQ020   1.0   2.0
# DIQ050
# 1.0      237   384
# 2.0     5246  8742
#
# chisquare p-value:
# 0.7715344468092364
#
#
# INDFMMPC
# Cross table result:
# BPQ020     1.0   2.0
# INDFMMPC
# 1.0       1846  3090
# 2.0        785  1314
# 3.0       2852  4722
#
# chisquare p-value:
# 0.9501447040033001
#
#
# KIQ022
# Cross table result:
# BPQ020   1.0   2.0
# KIQ022
# 1.0      190   339
# 2.0     5284  8770
# 9.0        9    17
#
# chisquare p-value:
# 0.7015450073069522
#
#
# KIQ044
# Cross table result:
# BPQ020   1.0   2.0
# KIQ044
# 1.0     1143  2005
# 2.0     4340  7121
#
# chisquare p-value:
# 0.11432313060501724
#
#
# KIQ480
# Cross table result:
# BPQ020         1.0   2.0
# KIQ480
# 5.397605e-79  1451  2407
# 1.000000e+00  2379  3977
# 2.000000e+00   953  1596
# 3.000000e+00   419   729
# 4.000000e+00   169   229
# 5.000000e+00   112   188
#
# chisquare p-value:
# 0.45148506560213797
#
#
# KIQ005
# Cross table result:
# BPQ020   1.0   2.0
# KIQ005
# 1.0     3979  6523
# 2.0      458   843
# 3.0      457   808
# 4.0      282   442
# 5.0      307   510
#
# chisquare p-value:
# 0.26129943621673646
#
#
# KIQ026
# Cross table result:
# BPQ020   1.0   2.0
# KIQ026
# 1.0      498   855
# 2.0     4973  8248
# 9.0       12    23
#
# chisquare p-value:
# 0.7792452033386231
#
#
# KIQ042
# Cross table result:
# BPQ020   1.0   2.0
# KIQ042
# 1.0     1133  1965
# 2.0     4350  7161
#
# chisquare p-value:
# 0.22175723589547564
#
#
# KIQ046
# Cross table result:
# BPQ020   1.0   2.0
# KIQ046
# 1.0      428   723
# 2.0     5055  8403
#
# chisquare p-value:
# 0.8248502939301745
#
#
# PAQ620
# Cross table result:
# BPQ020   1.0   2.0
# PAQ620
# 1.0     2023  3332
# 2.0     3460  5794
#
# chisquare p-value:
# 0.6529846929755154
#
#
# PAQ605
# Cross table result:
# BPQ020   1.0   2.0
# PAQ605
# 1.0     1044  1786
# 2.0     4439  7340
#
# chisquare p-value:
# 0.4455114380315641
#
#
# PAD680
# Cross table result:
# BPQ020        1.0   2.0
# PAD680
# 5.397605e-79    4     4
# 1.000000e+00    2     3
# 2.000000e+00    2     2
# 3.000000e+00    0     3
# 5.000000e+00    1     3
# 6.000000e+00    2     2
# 1.000000e+01    6     9
# 1.100000e+01    1     1
# 1.200000e+01    0     2
# 1.500000e+01   10    15
# 2.000000e+01   20    16
# 2.500000e+01    1     1
# 2.900000e+01    0     1
# 3.000000e+01   51    93
# 3.500000e+01    0     1
# 4.000000e+01    4     8
# 4.500000e+01    7    14
# 5.000000e+01    1     1
# 6.000000e+01  193   391
# 7.500000e+01    0     1
# 8.000000e+01    1     0
# 9.000000e+01   29    42
# 1.000000e+02    1     0
# 1.200000e+02  560   953
# 1.500000e+02    9     7
# 1.600000e+02    0     1
# 1.700000e+02    0     1
# 1.800000e+02  665  1068
# 2.000000e+02    1     0
# 2.100000e+02    0     5
# 2.300000e+02    1     0
# 2.400000e+02  757  1208
# 2.700000e+02    1     1
# 3.000000e+02  610   937
# 3.300000e+02    1     0
# 3.600000e+02  572   989
# 3.900000e+02    0     2
# 4.000000e+02    1     0
# 4.200000e+02  215   405
# 4.400000e+02    0     1
# 4.800000e+02  696  1158
# 5.400000e+02  146   282
# 5.850000e+02    1     0
# 6.000000e+02  426   687
# 6.600000e+02   65   104
# 7.200000e+02  256   419
# 7.800000e+02   20    45
# 8.400000e+02   55   110
# 9.000000e+02   37    58
# 9.600000e+02   35    41
# 1.020000e+03    6     6
# 1.080000e+03    8    19
# 1.140000e+03    0     2
# 1.200000e+03    3     2
# 1.320000e+03    0     1
# 1.380000e+03    0     1
#
# chisquare p-value:
# 0.4110979378087445
#
#
# PAQ650
# Cross table result:
# BPQ020   1.0   2.0
# PAQ650
# 1.0     1195  1914
# 2.0     4288  7212
#
# chisquare p-value:
# 0.24853734125971996
#
#
# PAQ665
# Cross table result:
# BPQ020   1.0   2.0
# PAQ665
# 1.0     2137  3571
# 2.0     3346  5552
# 9.0        0     3
#
# chisquare p-value:
# 0.39785890138155966
#
#
# PAQ635
# Cross table result:
# BPQ020   1.0   2.0
# PAQ635
# 1.0     1369  2291
# 2.0     4114  6835
#
# chisquare p-value:
# 0.8697407389866035
#
#
# SMQ020
# Cross table result:
# BPQ020   1.0   2.0
# SMQ020
# 1.0     2424  3983
# 2.0     3057  5135
# 7.0        0     3
# 9.0        2     5
#
# chisquare p-value:
# 0.48394221866342946
#
#
# BPAARM
# Cross table result:
# BPQ020   1.0   2.0
# BPAARM
# 1.0     5450  9081
# 2.0       31    44
# 8.0        2     1
#
# chisquare p-value:
# 0.4601133063223488
#
#
# BPXPULS
# Cross table result:
# BPQ020    1.0   2.0
# BPXPULS
# 1.0      5371  8942
# 2.0       112   184
#
# chisquare p-value:
# 0.9607019168719357
#
#
# BPAEN3
# Cross table result:
# BPQ020   1.0   2.0
# BPAEN3
# 1.0       97   154
# 2.0     5386  8972
#
# chisquare p-value:
# 0.7627713619742639

# %% [markdown]
# Comment: based on the table above, DIQ010 (p-value = 0.014809063221375079), KIQ022 (p-value = 0.012174178759029795), BPAEN3 (p-value = 0.08619622503848652) are related to the response variable. Therefore I would consider including these 3 features in the final model.

# %% [markdown]
# ### Feature selection on numeric variables

# %% [markdown]
# #### Correlation between numeric variables

# %%
numeric_featuers.corr()
# Out:
#           INDFMPIR  DSDCOUNT  DSDANCNT    ALQ130   LBDTCSI     LBXTC  \
# INDFMPIR  1.000000  0.179941  0.045759 -0.181037  0.037483  0.037471
# DSDCOUNT  0.179941  1.000000  0.064393 -0.145363  0.049912  0.049930
# DSDANCNT  0.045759  0.064393  1.000000 -0.008618  0.024366  0.024380
# ALQ130   -0.181037 -0.145363 -0.008618  1.000000  0.007305  0.007279
# LBDTCSI   0.037483  0.049912  0.024366  0.007305  1.000000  0.999996
# LBXTC     0.037471  0.049930  0.024380  0.007279  0.999996  1.000000
# KIQ480   -0.143655  0.041161  0.029365 -0.017177 -0.002500 -0.002492
# PAD680    0.175878  0.048943  0.042740 -0.061729 -0.038494 -0.038451
# LBXTR    -0.040612 -0.018499  0.042981  0.088535  0.340143  0.340165
# LBDTRSI  -0.040613 -0.018500  0.042977  0.088537  0.340141  0.340163
# LBDLDL    0.018039  0.004692  0.006469  0.006904  0.923314  0.923325
# LBDLDLSI  0.018038  0.004688  0.006470  0.006904  0.923315  0.923326
# BPXDI2    0.042175 -0.048371  0.015085  0.034644  0.135890  0.135885
# BPXDI3    0.036834 -0.054891  0.012262  0.037449  0.123180  0.123178
# BPXML1   -0.039905  0.029659 -0.000629 -0.019904  0.082138  0.082138
# BPXSY2   -0.058212  0.039027  0.004099 -0.014571  0.105729  0.105691
# BPXSY1   -0.059223  0.042242  0.004614 -0.019803  0.103837  0.103803
# BPXDI1    0.041830 -0.043609  0.010151  0.034706  0.143302  0.143274
# BPXPLS   -0.072427 -0.040242  0.027115  0.040189  0.063376  0.063349
# BPXSY3   -0.055634  0.037489  0.002245 -0.009249  0.097856  0.097828
#
#             KIQ480    PAD680     LBXTR   LBDTRSI    LBDLDL  LBDLDLSI  \
# INDFMPIR -0.143655  0.175878 -0.040612 -0.040613  0.018039  0.018038
# DSDCOUNT  0.041161  0.048943 -0.018499 -0.018500  0.004692  0.004688
# DSDANCNT  0.029365  0.042740  0.042981  0.042977  0.006469  0.006470
# ALQ130   -0.017177 -0.061729  0.088535  0.088537  0.006904  0.006904
# LBDTCSI  -0.002500 -0.038494  0.340143  0.340141  0.923314  0.923315
# LBXTC    -0.002492 -0.038451  0.340165  0.340163  0.923325  0.923326
# KIQ480    1.000000 -0.015692  0.028355  0.028355 -0.032830 -0.032832
# PAD680   -0.015692  1.000000  0.011109  0.011108 -0.037428 -0.037429
# LBXTR     0.028355  0.011109  1.000000  1.000000  0.189865  0.189865
# LBDTRSI   0.028355  0.011108  1.000000  1.000000  0.189860  0.189860
# LBDLDL   -0.032830 -0.037428  0.189865  0.189860  1.000000  1.000000
# LBDLDLSI -0.032832 -0.037429  0.189865  0.189860  1.000000  1.000000
# BPXDI2   -0.005482 -0.001208  0.093102  0.093103  0.134499  0.134500
# BPXDI3   -0.009882  0.002229  0.086930  0.086932  0.121252  0.121256
# BPXML1    0.130082 -0.004352  0.071375  0.071377  0.057765  0.057765
# BPXSY2    0.174925 -0.018039  0.098612  0.098614  0.073175  0.073180
# BPXSY1    0.180403 -0.036806  0.103068  0.103069  0.069238  0.069243
# BPXDI1    0.006159  0.000162  0.091871  0.091871  0.137379  0.137382
# BPXPLS    0.035463  0.070863  0.096238  0.096237  0.029034  0.029034
# BPXSY3    0.168026 -0.014767  0.093725  0.093726  0.066441  0.066446
#
#             BPXDI2    BPXDI3    BPXML1    BPXSY2    BPXSY1    BPXDI1  \
# INDFMPIR  0.042175  0.036834 -0.039905 -0.058212 -0.059223  0.041830
# DSDCOUNT -0.048371 -0.054891  0.029659  0.039027  0.042242 -0.043609
# DSDANCNT  0.015085  0.012262 -0.000629  0.004099  0.004614  0.010151
# ALQ130    0.034644  0.037449 -0.019904 -0.014571 -0.019803  0.034706
# LBDTCSI   0.135890  0.123180  0.082138  0.105729  0.103837  0.143302
# LBXTC     0.135885  0.123178  0.082138  0.105691  0.103803  0.143274
# KIQ480   -0.005482 -0.009882  0.130082  0.174925  0.180403  0.006159
# PAD680   -0.001208  0.002229 -0.004352 -0.018039 -0.036806  0.000162
# LBXTR     0.093102  0.086930  0.071375  0.098612  0.103068  0.091871
# LBDTRSI   0.093103  0.086932  0.071377  0.098614  0.103069  0.091871
# LBDLDL    0.134499  0.121252  0.057765  0.073175  0.069238  0.137379
# LBDLDLSI  0.134500  0.121256  0.057765  0.073180  0.069243  0.137382
# BPXDI2    1.000000  0.891380  0.247615  0.298167  0.272348  0.870329
# BPXDI3    0.891380  1.000000  0.228529  0.277075  0.249266  0.854980
# BPXML1    0.247615  0.228529  1.000000  0.889672  0.904151  0.273192
# BPXSY2    0.298167  0.277075  0.889672  1.000000  0.952878  0.333106
# BPXSY1    0.272348  0.249266  0.904151  0.952878  1.000000  0.307681
# BPXDI1    0.870329  0.854980  0.273192  0.333106  0.307681  1.000000
# BPXPLS    0.102032  0.105028 -0.058052 -0.045569 -0.057261  0.102855
# BPXSY3    0.310193  0.293439  0.876171  0.957870  0.940843  0.339607
#
#             BPXPLS    BPXSY3
# INDFMPIR -0.072427 -0.055634
# DSDCOUNT -0.040242  0.037489
# DSDANCNT  0.027115  0.002245
# ALQ130    0.040189 -0.009249
# LBDTCSI   0.063376  0.097856
# LBXTC     0.063349  0.097828
# KIQ480    0.035463  0.168026
# PAD680    0.070863 -0.014767
# LBXTR     0.096238  0.093725
# LBDTRSI   0.096237  0.093726
# LBDLDL    0.029034  0.066441
# LBDLDLSI  0.029034  0.066446
# BPXDI2    0.102032  0.310193
# BPXDI3    0.105028  0.293439
# BPXML1   -0.058052  0.876171
# BPXSY2   -0.045569  0.957870
# BPXSY1   -0.057261  0.940843
# BPXDI1    0.102855  0.339607
# BPXPLS    1.000000 -0.040723
# BPXSY3   -0.040723  1.000000

# %% [markdown]
# Based on the table above,
# - LBDTCSI has high correlation with LBXTC, LBDLDL, LBDLDLSI
# - LBXTC has high correlation with LBDTCSI, LBDLDL, LBDLDLSI
# - LBXTR has high correlation with LBDTRSI
# - BPXDI2 has high correlation with BPXDI1, BPXDI3
# - BPXML1 has high correlation with BPXSY1, BPXSY2, BPXSY3
# - BPXSY2 has high correlation with BPXSY1, BPXSY3
#
# Therefore
# - if I decide to include LBDTCSI in the final model, I wouldn't include LBXTC, LBDLDL, LBDLDLSI
# - if I decided to include LBXTC, I wouldnt include LBDTCSI, LBDLDL, LBDLDLSI
# - if I include LBXTR, i wouldn't include LBDTRSI
# - if I include BPXDI1, I wouldn't include BPXDI2, BPXDI3
# - if I include BPXSY1, I wouldn't include BPXSY2, BPXSY3
# - if I include BPXML1, i woudln't include BPXSY1, BPXSY2, BPXSY3.
#
#
# For testing purposes, I will be excluding LBXTC, LBDLDL, LBDLDLSI, LBDTRSI, BPXSY1, BPXSY2, BPXSY3, BPXDI1, BPXDI3 to carry out further study regarding the correlation between numeric variables and the response variable.

# %%
numeric_features = numeric_featuers.drop(labels=['LBXTC', 'LBDLDL', 'LBDLDLSI', 'LBDTRSI', 'BPXSY1', 'BPXSY2', 'BPXSY3', 'BPXDI1', 
                             'BPXDI3'], axis=1)

# %%
# # filling in all the missing values in the median using simple imputer.
# imp_numeric = SimpleImputer(missing_values=np.nan, strategy='median')
# numeric_feats_transformed = imp_numeric.fit_transform(numeric_features)
# numeric_feats_transformed = pd.DataFrame(numeric_feats_transformed, columns=numeric_features.columns)
# numeric_feats_transformed.isnull().sum()

# %% [markdown]
# #### Correlation between numeric variables and the response variable

# %% [markdown]
# Comment: to test the correlation between the numeric features and the response variable (binary), i will be using the pointbiserial correlation method.
#
# Reference: https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.pointbiserialr.html#:~:text=The%20point%20biserial%20correlation%20is,1%20imply%20a%20determinative%20relationship.

# %%
# filling in all the missing values in the median using simple imputer.
imp_numeric = SimpleImputer(missing_values=np.nan, strategy='median')
numeric_feats_transformed = imp_numeric.fit_transform(numeric_features)
numeric_feats_transformed = pd.DataFrame(numeric_feats_transformed, columns=numeric_features.columns)
numeric_feats_transformed.isnull().sum()

numeric_features = numeric_feats_transformed.columns

def numeric_correlation(feature):
    print("feature: ", feature)
    y = final_df_2['BPQ020']
    result = stats.pointbiserialr(numeric_feats_transformed['INDFMPIR'], y)
    print("Correlation:")
    print(result[0])
    print("p-value:")
    print(result[1])
    print("\n")
    
for i in range(len(numeric_features)):
    numeric_correlation(numeric_features[i])
# Out:
# feature:  INDFMPIR
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  DSDCOUNT
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  DSDANCNT
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  ALQ130
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  LBDTCSI
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  KIQ480
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  PAD680
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  LBXTR
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  BPXDI2
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  BPXML1
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584
#
#
# feature:  BPXPLS
# Correlation:
# 0.029952422983980216
# p-value:
# 0.00014086808083087584

# %% [markdown]
# Based on the table above, it appears that no numeric features have an significant correlation with the réponse feature.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Extracting risk factors of hypertension into a new df
final= pd.read_csv('final.csv')
# hyp_nhanes = pd.DataFrame().assign(ID = final['SEQN'],hypertension=final['BPQ020'],alc_cons=final['ALQ130'], 
# income_pvrtind= final['INDFMMPI'],income_pvrtcat=final['INDFMMPC'],race=final['RIDRETH1'],
# edu_lvl_adult=final['DMDEDUC2'],age=final['RIDAGEYR'],gender=final['RIAGENDR'],avg_cig30d=final['SMD650'],
# smoke_now=final['SMQ040'],smoke_100xlife=final['SMQ020'],age_smoked_reg=final['SMD030'],chl_mgdl=final['LBXTC'],
# bmi_index=final['BMXBMI'], weight_kg=final['BMXWT'],pulse=final['BPXPLS'],vig_act=final['PAQ605'],mod_act=final['PAQ620'],
# vig_recre_ex=final['PAQ650'],mod_recre_ex=final['PAQ665'],triglyceride=final['LBXTR'],ldl_chol = final['LBDLDL'])
# Out:
# /Users/vanbanguyen0901/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (165) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
final= pd.read_csv('final.csv')

hyp_nhanes = final[['SEQN','BPQ020','ALQ130','INDFMMPI','INDFMMPC','RIDRETH1','DMDEDUC2','RIDAGEYR',
              'RIAGENDR','SMD650','SMQ040','SMQ020','SMD030','LBXTC','BMXBMI','BMXWT','BPXPLS',
              'PAQ605','PAQ620','PAQ650','PAQ665','LBXTR','LBDLDL', 'DIQ010', 'BPAEN3']]

values = [7,8,9,77,99,777,999,7777,9999]
hyp_nhanes = hyp_nhanes[hyp_nhanes["BPQ020"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["ALQ130"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["INDFMMPI"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["INDFMMPC"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["RIDRETH1"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["DMDEDUC2"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["RIDAGEYR"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["RIAGENDR"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["SMD650"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["SMQ040"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["SMQ020"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["SMD030"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["LBXTC"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["BMXBMI"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["BMXWT"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["BPXPLS"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["PAQ605"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["PAQ620"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["PAQ650"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["PAQ665"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["LBXTR"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["LBDLDL"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["DIQ010"].isin(values) == False]
hyp_nhanes = hyp_nhanes[hyp_nhanes["BPAEN3"].isin(values) == False]

hyp_nhanes.columns = ['ID','hypertension','alc_cons','income_pvrtind','income_pvrtcat','race','edu_lvl_adult',
                'age','gender','avg_cig30d','smoke_now','smoke_100xlife','age_smoked_reg','chl_mgdl','bmi_index',
                'weight_kg','pulse','vig_act','mod_act','vig_recre_ex','mod_recre_ex','triglyceride','ldl_chol', 
                'doctor_diabetes', 'enhancement_used']

# %%
hyp_nhanes.head()
# Out:
#          ID  hypertension  alc_cons  income_pvrtind  income_pvrtcat  race  \
# 0  109271.0           2.0       NaN            1.20             1.0   3.0
# 1  109274.0           1.0       2.0            1.20             1.0   5.0
# 2  109282.0           1.0       NaN            3.18             3.0   3.0
# 3  109286.0           2.0       NaN            1.22             1.0   5.0
# 4  109290.0           1.0       NaN            4.80             3.0   4.0
#
#    edu_lvl_adult   age  gender  avg_cig30d  ...  weight_kg      pulse  \
# 0            2.0  49.0     1.0        20.0  ...       98.8  71.333333
# 1            4.0  68.0     1.0         NaN  ...      103.7        NaN
# 2            5.0  76.0     1.0         NaN  ...       83.3  55.000000
# 3            5.0  33.0     2.0         NaN  ...       72.6        NaN
# 4            5.0  68.0     2.0         NaN  ...       73.0  58.000000
#
#    vig_act  mod_act  vig_recre_ex  mod_recre_ex  triglyceride  ldl_chol  \
# 0      2.0      1.0           2.0           2.0          84.0      97.0
# 1      1.0      1.0           2.0           1.0         133.0      49.0
# 2      2.0      2.0           2.0           2.0         132.0     164.0
# 3      2.0      2.0           2.0           2.0         192.0     131.0
# 4      2.0      1.0           2.0           1.0         102.0     105.0
#
#    doctor_diabetes  enhancement_used
# 0              2.0               NaN
# 1              1.0               NaN
# 2              2.0               NaN
# 3              2.0               NaN
# 4              1.0               NaN
#
# [5 rows x 25 columns]

# %%
hyp_nhanes_response = ['hypertension']

hyp_nhanes_numeric = ['ID', 'alc_cons','age','avg_cig30d','age_smoked_reg','chl_mgdl','bmi_index','weight_kg',
                      'pulse', 'triglyceride', 'ldl_chol']

hyp_nhanes_categorical = ['income_pvrtind', 'income_pvrtcat', 'race', 'edu_lvl_adult',
                          'gender','smoke_100xlife','smoke_now','vig_act', 'mod_act',
                          'vig_recre_ex','mod_recre_ex','doctor_diabetes', 'enhancement_used']

hyp_nhanes_response_feature = hyp_nhanes[hyp_nhanes_response]

hyp_nhanes_numeric_features = hyp_nhanes[hyp_nhanes_numeric]

hyp_nhanes_categorical_features = hyp_nhanes[hyp_nhanes_categorical]

# %%
# using simple imputer (median) to fill in all missing value for numeric features.
imp_numeric = SimpleImputer(missing_values=np.nan, strategy='median')
hyp_nhanes_numeric_features_transformed = imp_numeric.fit_transform(hyp_nhanes_numeric_features)
hyp_nhanes_numeric_features_transformed = pd.DataFrame(hyp_nhanes_numeric_features_transformed, columns=hyp_nhanes_numeric_features.columns)

# %%
hyp_nhanes_numeric_features_transformed.head()
# Out:
#          ID  alc_cons   age  avg_cig30d  age_smoked_reg  chl_mgdl  bmi_index  \
# 0  109271.0       2.0  49.0        20.0            18.0     147.0       29.7
# 1  109274.0       2.0  68.0        10.0            17.0     105.0       30.2
# 2  109282.0       2.0  76.0        10.0            18.0     233.0       26.6
# 3  109286.0       2.0  33.0        10.0            17.0     236.0       28.9
# 4  109290.0       2.0  68.0        10.0            17.0     165.0       28.1
#
#    weight_kg      pulse  triglyceride  ldl_chol
# 0       98.8  71.333333          84.0      97.0
# 1      103.7  70.000000         133.0      49.0
# 2       83.3  55.000000         132.0     164.0
# 3       72.6  70.000000         192.0     131.0
# 4       73.0  58.000000         102.0     105.0

# %%
# using simpleimputer (mode) to fill in the missing value for categorical features.
imp_categorical = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
hyp_nhanes_categorical_features_transformed = imp_categorical.fit_transform(hyp_nhanes_categorical_features)
hyp_nhanes_categorical_features_transformed = pd.DataFrame(hyp_nhanes_categorical_features_transformed, columns=hyp_nhanes_categorical_features.columns)

# %%
hyp_nhanes_categorical_features_transformed
# Out:
#        income_pvrtind  income_pvrtcat  race  edu_lvl_adult  gender  \
# 0                1.20             1.0   3.0            2.0     1.0
# 1                1.20             1.0   5.0            4.0     1.0
# 2                3.18             3.0   3.0            5.0     1.0
# 3                1.22             1.0   5.0            5.0     2.0
# 4                4.80             3.0   4.0            5.0     2.0
# ...               ...             ...   ...            ...     ...
# 15923            3.86             3.0   3.0            3.0     1.0
# 15924            2.73             3.0   2.0            1.0     2.0
# 15925            3.82             3.0   3.0            5.0     1.0
# 15926            2.63             3.0   3.0            2.0     2.0
# 15927            5.00             3.0   3.0            1.0     1.0
#
#        smoke_100xlife  smoke_now  vig_act  mod_act  vig_recre_ex  \
# 0                 1.0        1.0      2.0      1.0           2.0
# 1                 2.0        3.0      1.0      1.0           2.0
# 2                 1.0        3.0      2.0      2.0           2.0
# 3                 2.0        3.0      2.0      2.0           2.0
# 4                 2.0        3.0      2.0      1.0           2.0
# ...               ...        ...      ...      ...           ...
# 15923             1.0        1.0      2.0      2.0           2.0
# 15924             2.0        3.0      2.0      2.0           2.0
# 15925             2.0        3.0      2.0      2.0           2.0
# 15926             1.0        3.0      1.0      1.0           2.0
# 15927             1.0        1.0      2.0      2.0           2.0
#
#        mod_recre_ex  doctor_diabetes  enhancement_used
# 0               2.0              2.0               2.0
# 1               1.0              1.0               2.0
# 2               2.0              2.0               2.0
# 3               2.0              2.0               2.0
# 4               1.0              1.0               2.0
# ...             ...              ...               ...
# 15923           2.0              1.0               2.0
# 15924           2.0              2.0               2.0
# 15925           2.0              2.0               2.0
# 15926           2.0              2.0               2.0
# 15927           2.0              2.0               2.0
#
# [15928 rows x 13 columns]

# %%
hyp_nhanes_transformed = pd.concat([hyp_nhanes_numeric_features_transformed, hyp_nhanes_categorical_features_transformed], axis=1, join='inner')

# %% [markdown]
# ### Variables

# %%
# #List of columns/features
hyp_nhanes_transformed.columns
# Out:
# Index(['ID', 'alc_cons', 'age', 'avg_cig30d', 'age_smoked_reg', 'chl_mgdl',
#        'bmi_index', 'weight_kg', 'pulse', 'triglyceride', 'ldl_chol',
#        'income_pvrtind', 'income_pvrtcat', 'race', 'edu_lvl_adult', 'gender',
#        'smoke_100xlife', 'smoke_now', 'vig_act', 'mod_act', 'vig_recre_ex',
#        'mod_recre_ex', 'doctor_diabetes', 'enhancement_used'],
#       dtype='object')

# %%
hyp_nhanes_response_feature.columns
# Out:
# Index(['hypertension'], dtype='object')

# %% [markdown]
# ### Missing Values

# %%
#Count how many NaN values in the df
n_na = hyp_nhanes.isna().sum()
display(n_na)
# Out:
# ID                      0
# hypertension            0
# alc_cons             6224
# income_pvrtind       1988
# income_pvrtcat        830
# race                    0
# edu_lvl_adult           0
# age                     0
# gender                  0
# avg_cig30d          13016
# smoke_now            9156
# smoke_100xlife          1
# age_smoked_reg       9156
# chl_mgdl              986
# bmi_index             230
# weight_kg             200
# pulse                1122
# vig_act                 0
# mod_act                 0
# vig_recre_ex            0
# mod_recre_ex            0
# triglyceride         1169
# ldl_chol             1398
# doctor_diabetes         0
# enhancement_used     4252
# dtype: int64

# %%
#Calculating the percentage of missing values in each column
percentage_na= (hyp_nhanes.isna().sum() * 100 / len(hyp_nhanes)).round(2)

#Creating a new df
miss_val = pd.DataFrame({ 'Total Number of missing values':n_na,
                                 'Percentage of missing values': percentage_na})

#extract rows based on a condition
missing = miss_val['Percentage of missing values'] > 0
#New data frame with the extracted rows
NaN_df = pd.DataFrame(miss_val[missing])

print('Total number and percentage of missing values')
NaN_df
# Out:
# Total number and percentage of missing values
#                   Total Number of missing values  Percentage of missing values
# alc_cons                                    6224                         39.08
# income_pvrtind                              1988                         12.48
# income_pvrtcat                               830                          5.21
# avg_cig30d                                 13016                         81.72
# smoke_now                                   9156                         57.48
# smoke_100xlife                                 1                          0.01
# age_smoked_reg                              9156                         57.48
# chl_mgdl                                     986                          6.19
# bmi_index                                    230                          1.44
# weight_kg                                    200                          1.26
# pulse                                       1122                          7.04
# triglyceride                                1169                          7.34
# ldl_chol                                    1398                          8.78
# enhancement_used                            4252                         26.70

# %% [markdown]
# Comment: It appears that avg_cig30d has 80% of its value being NaN, therefore i will remove that column in the hyp_nhanes_transformed dataframe.

# %%
hyp_nhanes_transformed = hyp_nhanes_transformed.drop('avg_cig30d', axis=1)

# %%
hyp_nhanes_transformed.columns
# Out:
# Index(['ID', 'alc_cons', 'age', 'age_smoked_reg', 'chl_mgdl', 'bmi_index',
#        'weight_kg', 'pulse', 'triglyceride', 'ldl_chol', 'income_pvrtind',
#        'income_pvrtcat', 'race', 'edu_lvl_adult', 'gender', 'smoke_100xlife',
#        'smoke_now', 'vig_act', 'mod_act', 'vig_recre_ex', 'mod_recre_ex',
#        'doctor_diabetes', 'enhancement_used'],
#       dtype='object')

# %% [markdown]
# ### Stats

# %%
#Summary Statistics
display(hyp_nhanes_transformed.describe().round(2))
# Out:
#               ID  alc_cons       age  age_smoked_reg  chl_mgdl  bmi_index  \
# count   15928.00  15928.00  15928.00        15928.00  15928.00   15928.00
# mean    78811.52      2.37     50.12           17.30    191.22      29.24
# std     25128.91      1.94     17.49            4.07     40.79       7.06
# min     41481.00      1.00     20.00            0.00     69.00      13.40
# 25%     57701.25      2.00     35.00           17.00    164.00      24.40
# 50%     75749.00      2.00     50.00           17.00    188.00      28.10
# 75%     92610.25      2.00     64.00           17.00    214.00      32.60
# max    124822.00     66.00     80.00           74.00    612.00      92.30
#
#        weight_kg     pulse  triglyceride  ldl_chol  ...  edu_lvl_adult  \
# count   15928.00  15928.00      15928.00  15928.00  ...       15928.00
# mean       81.77     71.01        121.96    113.03  ...           3.44
# std        21.80     11.35        105.72     34.17  ...           1.27
# min        29.10     36.00         10.00     15.00  ...           1.00
# 25%        66.60     64.00         71.00     90.00  ...           3.00
# 50%        78.60     70.00        101.00    111.00  ...           4.00
# 75%        93.00     78.00        143.00    132.00  ...           4.00
# max       254.30    160.00       4233.00    375.00  ...           5.00
#
#          gender  smoke_100xlife  smoke_now   vig_act   mod_act  vig_recre_ex  \
# count  15928.00        15928.00   15928.00  15928.00  15928.00      15928.00
# mean       1.52            1.57       2.67      1.81      1.63          1.79
# std        0.50            0.49       0.72      0.40      0.48          0.41
# min        1.00            1.00       1.00      1.00      1.00          1.00
# 25%        1.00            1.00       3.00      2.00      1.00          2.00
# 50%        2.00            2.00       3.00      2.00      2.00          2.00
# 75%        2.00            2.00       3.00      2.00      2.00          2.00
# max        2.00            2.00       3.00      2.00      2.00          2.00
#
#        mod_recre_ex  doctor_diabetes  enhancement_used
# count      15928.00         15928.00          15928.00
# mean           1.60             1.89              1.98
# std            0.49             0.39              0.13
# min            1.00             1.00              1.00
# 25%            1.00             2.00              2.00
# 50%            2.00             2.00              2.00
# 75%            2.00             2.00              2.00
# max            2.00             3.00              2.00
#
# [8 rows x 23 columns]

# %%
hyp_nhanes_numeric_features_transformed.describe()
# Out:
#                   ID      alc_cons           age    avg_cig30d  \
# count   15928.000000  15928.000000  15928.000000  15928.000000
# mean    78811.524046      2.367403     50.116838     10.361690
# std     25128.913659      1.944091     17.491692      4.358555
# min     41481.000000      1.000000     20.000000      1.000000
# 25%     57701.250000      2.000000     35.000000     10.000000
# 50%     75749.000000      2.000000     50.000000     10.000000
# 75%     92610.250000      2.000000     64.000000     10.000000
# max    124822.000000     66.000000     80.000000     95.000000
#
#        age_smoked_reg      chl_mgdl     bmi_index     weight_kg         pulse  \
# count    1.592800e+04  15928.000000  15928.000000  15928.000000  15928.000000
# mean     1.729502e+01    191.217228     29.238331     81.768571     71.014168
# std      4.068238e+00     40.788319      7.056268     21.795243     11.351462
# min      5.397605e-79     69.000000     13.400000     29.100000     36.000000
# 25%      1.700000e+01    164.000000     24.400000     66.600000     64.000000
# 50%      1.700000e+01    188.000000     28.100000     78.600000     70.000000
# 75%      1.700000e+01    214.000000     32.600000     93.000000     78.000000
# max      7.400000e+01    612.000000     92.300000    254.300000    160.000000
#
#        triglyceride      ldl_chol
# count  15928.000000  15928.000000
# mean     121.960070    113.029759
# std      105.724073     34.172122
# min       10.000000     15.000000
# 25%       71.000000     90.000000
# 50%      101.000000    111.000000
# 75%      143.000000    132.000000
# max     4233.000000    375.000000

# %%
hyp_nhanes_categorical_features_transformed.describe()
# Out:
#        income_pvrtind  income_pvrtcat          race  edu_lvl_adult  \
# count    1.592800e+04    15928.000000  15928.000000   15928.000000
# mean     2.634189e+00        2.193182      3.085824       3.442177
# std      1.707395e+00        0.904791      1.183796       1.268023
# min      5.397605e-79        1.000000      1.000000       1.000000
# 25%      1.110000e+00        1.000000      3.000000       3.000000
# 50%      2.200000e+00        3.000000      3.000000       4.000000
# 75%      4.800000e+00        3.000000      4.000000       4.000000
# max      5.000000e+00        3.000000      5.000000       5.000000
#
#              gender  smoke_100xlife     smoke_now       vig_act       mod_act  \
# count  15928.000000    15928.000000  15928.000000  15928.000000  15928.000000
# mean       1.524046        1.574837      2.669199      1.805563      1.630211
# std        0.499437        0.494383      0.717005      0.395779      0.482763
# min        1.000000        1.000000      1.000000      1.000000      1.000000
# 25%        1.000000        1.000000      3.000000      2.000000      1.000000
# 50%        2.000000        2.000000      3.000000      2.000000      2.000000
# 75%        2.000000        2.000000      3.000000      2.000000      2.000000
# max        2.000000        2.000000      3.000000      2.000000      2.000000
#
#        vig_recre_ex  mod_recre_ex  doctor_diabetes  enhancement_used
# count  15928.000000  15928.000000     15928.000000      15928.000000
# mean       1.785535      1.601519         1.888184          1.982609
# std        0.410464      0.489601         0.385414          0.130726
# min        1.000000      1.000000         1.000000          1.000000
# 25%        2.000000      1.000000         2.000000          2.000000
# 50%        2.000000      2.000000         2.000000          2.000000
# 75%        2.000000      2.000000         2.000000          2.000000
# max        2.000000      2.000000         3.000000          2.000000

# %%
#hyp_df.hypertension.unique()

# %% [markdown]
# #### Distribution of numeric features:

# %%
hyp_nhanes_numeric = ['ID', 'alc_cons','age','age_smoked_reg','chl_mgdl','bmi_index','weight_kg',
                      'pulse', 'triglyceride', 'ldl_chol']

#Histograms - variables
fig = plt.figure(figsize = (20,20))
plt.title("Histogram of numeric feature")
ax = fig.gca()
hyp_nhanes_numeric_features_transformed.hist(ax=ax, grid=False, bins=10, color='green')
plt.show()
# Out:
# <ipython-input-62-dbddf79a69d9>:8: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   hyp_nhanes_numeric_features_transformed.hist(ax=ax, grid=False, bins=10, color='green')

# %% [markdown]
# #### Distribution of categorical features:

# %%
hyp_nhanes_categorical = ['income_pvrtind', 'income_pvrtcat', 'race', 'edu_lvl_adult',
                          'gender','smoke_100xlife','smoke_now','vig_act', 'mod_act',
                          'vig_recre_ex','mod_recre_ex','doctor_diabetes', 'enhancement_used']

#Histograms - variables
fig = plt.figure(figsize = (20,20))
plt.title("Histogram of categorical feature")
ax = fig.gca()
hyp_nhanes_categorical_features_transformed.hist(ax=ax, grid=False, bins=10, color='green')
plt.show()
# Out:
# <ipython-input-63-9c370c79a326>:9: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   hyp_nhanes_categorical_features_transformed.hist(ax=ax, grid=False, bins=10, color='green')

# %% [markdown]
# ### Relationship Analysis between variables

# %% [markdown]
# #### Relationship between numeric variables

# %%
hyp_nhanes_numeric_features_transformed.corr()
# Out:
#                       ID  alc_cons       age  avg_cig30d  age_smoked_reg  \
# ID              1.000000 -0.034982  0.014035   -0.054253        0.028571
# alc_cons       -0.034982  1.000000 -0.185836    0.042772       -0.032798
# age             0.014035 -0.185836  1.000000    0.017441        0.074683
# avg_cig30d     -0.054253  0.042772  0.017441    1.000000       -0.058328
# age_smoked_reg  0.028571 -0.032798  0.074683   -0.058328        1.000000
# chl_mgdl       -0.095722  0.005839  0.074343    0.011791        0.011153
# bmi_index       0.057044  0.019528  0.020563   -0.027734        0.002705
# weight_kg       0.041732  0.078697 -0.046980   -0.002843       -0.013647
# pulse          -0.087818  0.031998 -0.121688    0.056220        0.006119
# triglyceride   -0.088795  0.058864  0.049371    0.032979       -0.007755
# ldl_chol       -0.067931  0.001624  0.018964    0.017940        0.008407
#
#                 chl_mgdl  bmi_index  weight_kg     pulse  triglyceride  \
# ID             -0.095722   0.057044   0.041732 -0.087818     -0.088795
# alc_cons        0.005839   0.019528   0.078697  0.031998      0.058864
# age             0.074343   0.020563  -0.046980 -0.121688      0.049371
# avg_cig30d      0.011791  -0.027734  -0.002843  0.056220      0.032979
# age_smoked_reg  0.011153   0.002705  -0.013647  0.006119     -0.007755
# chl_mgdl        1.000000  -0.010871  -0.040115  0.055879      0.337305
# bmi_index      -0.010871   1.000000   0.884046  0.110689      0.122332
# weight_kg      -0.040115   0.884046   1.000000  0.074463      0.127811
# pulse           0.055879   0.110689   0.074463  1.000000      0.087867
# triglyceride    0.337305   0.122332   0.127811  0.087867      1.000000
# ldl_chol        0.886374   0.036165   0.024381  0.021798      0.109561
#
#                 ldl_chol
# ID             -0.067931
# alc_cons        0.001624
# age             0.018964
# avg_cig30d      0.017940
# age_smoked_reg  0.008407
# chl_mgdl        0.886374
# bmi_index       0.036165
# weight_kg       0.024381
# pulse           0.021798
# triglyceride    0.109561
# ldl_chol        1.000000

# %% [markdown]
# Comment: chl_mgdl and ldl_chol therefore we will remove ldl_chol.

# %% [markdown]
# #### Relationship between numeric variables and the response variable

# %%
hyp_nhanes_numeric_features_transformed = hyp_nhanes_numeric_features_transformed.drop('ldl_chol', axis=1)

# %%
numeric_features = hyp_nhanes_numeric_features_transformed.columns

def numeric_correlation(feature):
    print("feature: ", feature)
    y = hyp_nhanes_response_feature['hypertension']
    result = stats.pointbiserialr(hyp_nhanes_numeric_features_transformed[feature], y)
    print("Correlation:")
    print(result[0])
    print("p-value:")
    print(result[1])
    print("\n")
    
for i in range(len(numeric_features)):
    numeric_correlation(numeric_features[i])
# Out:
# feature:  ID
# Correlation:
# -0.012327221479670589
# p-value:
# 0.11977741365500381
#
#
# feature:  alc_cons
# Correlation:
# 0.05507162603825851
# p-value:
# 3.5228125896685577e-12
#
#
# feature:  age
# Correlation:
# -0.43162992971373615
# p-value:
# 0.0
#
#
# feature:  avg_cig30d
# Correlation:
# -0.024372696297266083
# p-value:
# 0.002096568670440812
#
#
# feature:  age_smoked_reg
# Correlation:
# -0.040798524207482645
# p-value:
# 2.594243560937052e-07
#
#
# feature:  chl_mgdl
# Correlation:
# 0.023468753801102724
# p-value:
# 0.003055710995575778
#
#
# feature:  bmi_index
# Correlation:
# -0.21625942584652802
# p-value:
# 6.6588987339130715e-168
#
#
# feature:  weight_kg
# Correlation:
# -0.1763879217149713
# p-value:
# 1.768338736851656e-111
#
#
# feature:  pulse
# Correlation:
# 9.996479254737128e-05
# p-value:
# 0.989934805947094
#
#
# feature:  triglyceride
# Correlation:
# -0.08009479823781411
# p-value:
# 4.326740508055736e-24

# %% [markdown]
# Comment: it appears that majority of the features by themselve do not have high correlation to the response variable. Some variables such as weight_kg, bmi_index and age have weak correlation with the response feature.

# %% [markdown]
# #### Relationship between categorical variable and response variable

# %%
categorical_features = hyp_nhanes_categorical_features_transformed.columns

def categorical_correlation(feature):
    CrosstabResult=pd.crosstab(index=hyp_nhanes_categorical_features_transformed[feature],
                               columns=hyp_nhanes_response_feature['hypertension'])
    print("Cross table result:")
    print(CrosstabResult)
    ChiSqResult = chi2_contingency(CrosstabResult)
    
    print("\nchisquare p-value:")
    print(ChiSqResult[1])
    print("\n")
    
    
for i in range(len(categorical_features)):
    categorical_correlation(categorical_features[i])
# Out:
# Cross table result:
# hypertension     1.0   2.0
# income_pvrtind
# 5.397605e-79      85   168
# 2.000000e-02       0     1
# 3.000000e-02       4     1
# 4.000000e-02       1     2
# 5.000000e-02       0     3
# ...              ...   ...
# 4.960000e+00       4     7
# 4.970000e+00       6    12
# 4.980000e+00       1     4
# 4.990000e+00       3     3
# 5.000000e+00    1275  2111
#
# [492 rows x 2 columns]
#
# chisquare p-value:
# 0.1466659665873854
#
#
# Cross table result:
# hypertension     1.0   2.0
# income_pvrtcat
# 1.0             1814  2930
# 2.0              766  1264
# 3.0             2757  4655
#
# chisquare p-value:
# 0.5093230621990504
#
#
# Cross table result:
# hypertension   1.0   2.0
# race
# 1.0            714  1290
# 2.0            613   925
# 3.0           2093  3598
# 4.0           1223  1895
# 5.0            694  1141
#
# chisquare p-value:
# 0.018611123256423782
#
#
# Cross table result:
# hypertension    1.0   2.0
# edu_lvl_adult
# 1.0             548   874
# 2.0             776  1220
# 3.0            1177  1989
# 4.0            1572  2597
# 5.0            1264  2169
#
# chisquare p-value:
# 0.5457354691936478
#
#
# Cross table result:
# hypertension   1.0   2.0
# gender
# 1.0           2595  4157
# 2.0           2742  4692
#
# chisquare p-value:
# 0.059563275769361886
#
#
# Cross table result:
# hypertension     1.0   2.0
# smoke_100xlife
# 1.0             2289  3726
# 2.0             3048  5123
#
# chisquare p-value:
# 0.3700259480803919
#
#
# Cross table result:
# hypertension   1.0   2.0
# smoke_now
# 1.0            789  1289
# 2.0            202   333
# 3.0           4346  7227
#
# chisquare p-value:
# 0.9349958349692316
#
#
# Cross table result:
# hypertension   1.0   2.0
# vig_act
# 1.0           1070  1694
# 2.0           4267  7155
#
# chisquare p-value:
# 0.19465393897111388
#
#
# Cross table result:
# hypertension   1.0   2.0
# mod_act
# 1.0           2025  3219
# 2.0           3312  5630
#
# chisquare p-value:
# 0.06381118660823754
#
#
# Cross table result:
# hypertension   1.0   2.0
# vig_recre_ex
# 1.0           1129  1930
# 2.0           4208  6919
#
# chisquare p-value:
# 0.36838147511035113
#
#
# Cross table result:
# hypertension   1.0   2.0
# mod_recre_ex
# 1.0           2090  3582
# 2.0           3247  5267
#
# chisquare p-value:
# 0.12468708863640664
#
#
# Cross table result:
# hypertension      1.0   2.0
# doctor_diabetes
# 1.0               717  1207
# 2.0              4487  7420
# 3.0               133   222
#
# chisquare p-value:
# 0.9385203318112216
#
#
# Cross table result:
# hypertension       1.0   2.0
# enhancement_used
# 1.0                 85   159
# 2.0               5252  8690
#
# chisquare p-value:
# 0.40126560737583095

# %% [markdown]
# Comment: from the table above, it appears that race, gender, mod_act, are related to the response variable since their p-values are very small.

# %%
# #Calculating spearman correlation between predictor variables and the target variable

import scipy 
import seaborn as sns
from scipy.stats import spearmanr
hyp_corr = hyp_nhanes_transformed.corr(method='spearman').round(2)
hyp_corr
# Out:
#                     ID  alc_cons   age  age_smoked_reg  chl_mgdl  bmi_index  \
# ID                1.00     -0.02  0.01            0.03     -0.10       0.04
# alc_cons         -0.02      1.00 -0.21           -0.04     -0.01       0.04
# age               0.01     -0.21  1.00            0.05      0.08       0.06
# age_smoked_reg    0.03     -0.04  0.05            1.00      0.01       0.00
# chl_mgdl         -0.10     -0.01  0.08            0.01      1.00       0.01
# bmi_index         0.04      0.04  0.06            0.00      0.01       1.00
# weight_kg         0.03      0.09 -0.02           -0.01     -0.03       0.86
# pulse            -0.07      0.05 -0.13           -0.01      0.05       0.09
# triglyceride     -0.14      0.05  0.14           -0.02      0.34       0.25
# ldl_chol         -0.07     -0.01  0.02            0.01      0.89       0.07
# income_pvrtind    0.06     -0.12  0.09            0.04      0.03      -0.05
# income_pvrtcat    0.03     -0.12  0.08            0.05      0.01      -0.04
# race              0.14     -0.10 -0.02            0.05     -0.04      -0.11
# edu_lvl_adult     0.09     -0.15 -0.12            0.07     -0.01      -0.08
# gender           -0.00     -0.17 -0.02            0.03      0.07       0.05
# smoke_100xlife    0.02     -0.14 -0.13           -0.05     -0.00      -0.00
# smoke_now         0.02     -0.19  0.11           -0.01     -0.01       0.06
# vig_act          -0.06     -0.11  0.14            0.03     -0.00      -0.03
# mod_act          -0.05     -0.05  0.13            0.01      0.00      -0.02
# vig_recre_ex     -0.04     -0.03  0.29           -0.01      0.03       0.12
# mod_recre_ex     -0.03      0.04  0.09           -0.04     -0.01       0.07
# doctor_diabetes  -0.02      0.03 -0.22            0.01      0.12      -0.14
# enhancement_used  0.01      0.01  0.01            0.00     -0.02       0.00
#
#                   weight_kg  pulse  triglyceride  ldl_chol  ...  \
# ID                     0.03  -0.07         -0.14     -0.07  ...
# alc_cons               0.09   0.05          0.05     -0.01  ...
# age                   -0.02  -0.13          0.14      0.02  ...
# age_smoked_reg        -0.01  -0.01         -0.02      0.01  ...
# chl_mgdl              -0.03   0.05          0.34      0.89  ...
# bmi_index              0.86   0.09          0.25      0.07  ...
# weight_kg              1.00   0.05          0.21      0.05  ...
# pulse                  0.05   1.00          0.10      0.02  ...
# triglyceride           0.21   0.10          1.00      0.24  ...
# ldl_chol               0.05   0.02          0.24      1.00  ...
# income_pvrtind         0.01  -0.06         -0.04      0.01  ...
# income_pvrtcat         0.03  -0.06         -0.05     -0.00  ...
# race                  -0.03  -0.01         -0.17     -0.04  ...
# edu_lvl_adult          0.02  -0.01         -0.13     -0.02  ...
# gender                -0.28   0.15         -0.10     -0.00  ...
# smoke_100xlife        -0.09   0.01         -0.11      0.01  ...
# smoke_now              0.00  -0.06         -0.06     -0.01  ...
# vig_act               -0.10   0.05          0.02     -0.03  ...
# mod_act               -0.08   0.03          0.03     -0.02  ...
# vig_recre_ex           0.02   0.10          0.13      0.01  ...
# mod_recre_ex           0.02   0.05          0.07      0.00  ...
# doctor_diabetes       -0.11  -0.04         -0.11      0.13  ...
# enhancement_used       0.00  -0.02         -0.00     -0.01  ...
#
#                   edu_lvl_adult  gender  smoke_100xlife  smoke_now  vig_act  \
# ID                         0.09   -0.00            0.02       0.02    -0.06
# alc_cons                  -0.15   -0.17           -0.14      -0.19    -0.11
# age                       -0.12   -0.02           -0.13       0.11     0.14
# age_smoked_reg             0.07    0.03           -0.05      -0.01     0.03
# chl_mgdl                  -0.01    0.07           -0.00      -0.01    -0.00
# bmi_index                 -0.08    0.05           -0.00       0.06    -0.03
# weight_kg                  0.02   -0.28           -0.09       0.00    -0.10
# pulse                     -0.01    0.15            0.01      -0.06     0.05
# triglyceride              -0.13   -0.10           -0.11      -0.06     0.02
# ldl_chol                  -0.02   -0.00            0.01      -0.01    -0.03
# income_pvrtind             0.34   -0.05            0.08       0.15     0.04
# income_pvrtcat             0.37   -0.05            0.08       0.16     0.02
# race                       0.24   -0.01            0.02      -0.04     0.06
# edu_lvl_adult              1.00    0.02            0.12       0.14     0.05
# gender                     0.02    1.00            0.19       0.08     0.18
# smoke_100xlife             0.12    0.19            1.00       0.55     0.09
# smoke_now                  0.14    0.08            0.55       1.00     0.10
# vig_act                    0.05    0.18            0.09       0.10     1.00
# mod_act                   -0.02    0.10            0.06       0.05     0.43
# vig_recre_ex              -0.23    0.12           -0.10      -0.07     0.08
# mod_recre_ex              -0.24    0.01           -0.05      -0.08     0.03
# doctor_diabetes            0.08    0.02            0.03      -0.03    -0.05
# enhancement_used          -0.03   -0.02           -0.01      -0.01    -0.01
#
#                   mod_act  vig_recre_ex  mod_recre_ex  doctor_diabetes  \
# ID                  -0.05         -0.04         -0.03            -0.02
# alc_cons            -0.05         -0.03          0.04             0.03
# age                  0.13          0.29          0.09            -0.22
# age_smoked_reg       0.01         -0.01         -0.04             0.01
# chl_mgdl             0.00          0.03         -0.01             0.12
# bmi_index           -0.02          0.12          0.07            -0.14
# weight_kg           -0.08          0.02          0.02            -0.11
# pulse                0.03          0.10          0.05            -0.04
# triglyceride         0.03          0.13          0.07            -0.11
# ldl_chol            -0.02          0.01          0.00             0.13
# income_pvrtind       0.01         -0.13         -0.13             0.02
# income_pvrtcat      -0.02         -0.13         -0.14             0.03
# race                 0.04         -0.06         -0.05             0.01
# edu_lvl_adult       -0.02         -0.23         -0.24             0.08
# gender               0.10          0.12          0.01             0.02
# smoke_100xlife       0.06         -0.10         -0.05             0.03
# smoke_now            0.05         -0.07         -0.08            -0.03
# vig_act              0.43          0.08          0.03            -0.05
# mod_act              1.00          0.09          0.10            -0.06
# vig_recre_ex         0.09          1.00          0.28            -0.11
# mod_recre_ex         0.10          0.28          1.00            -0.07
# doctor_diabetes     -0.06         -0.11         -0.07             1.00
# enhancement_used    -0.01         -0.00          0.02            -0.00
#
#                   enhancement_used
# ID                            0.01
# alc_cons                      0.01
# age                           0.01
# age_smoked_reg                0.00
# chl_mgdl                     -0.02
# bmi_index                     0.00
# weight_kg                     0.00
# pulse                        -0.02
# triglyceride                 -0.00
# ldl_chol                     -0.01
# income_pvrtind               -0.00
# income_pvrtcat               -0.01
# race                         -0.03
# edu_lvl_adult                -0.03
# gender                       -0.02
# smoke_100xlife               -0.01
# smoke_now                    -0.01
# vig_act                      -0.01
# mod_act                      -0.01
# vig_recre_ex                 -0.00
# mod_recre_ex                  0.02
# doctor_diabetes              -0.00
# enhancement_used              1.00
#
# [23 rows x 23 columns]

# %%
#Heatmap
import seaborn as sns
plt.figure(figsize=(20,20))
sns.heatmap(hyp_corr,yticklabels=hyp_corr, annot= True)
plt.title('Heatmap : displaying the relationships between variables',
         fontsize=25)
# Out:
# Text(0.5, 1.0, 'Heatmap : displaying the relationships between variables')

# %% [markdown]
# Variables significantly correlated with each other:
#
# - BMI and Weight
# - Income index and Income category.
#
# BMI is a more useful indicator whether an individual is overweight and is obese. It is a measure of body percentage which can be an effecitive predictor of hypertension.
#
# income_pvrtind (income_pvrtyind) represents the family monthly poverty index-  a ratio of family monthly income based on the HHS poverty guidelines.Income_pvrtcat are the catagories of these values.
#
#
# BMI and income_pvrtcat will be kept in the data set.

# %%
# Remove two columns name is 'weight' and 'income_pvrtind'
hypertension = hyp_df.drop(['weight_kg','income_pvrtind'], axis=1)
hypertension

# %%
hypertension.shape
